# %% [markdown]
# Assignment 1

# %% [markdown]
# Basic String Processing

# %% [markdown]
# Task 1:
# Print a string that displays 'NLP stands for Natural Language Processing' using the variables provided.

# %%
abbr = 'NLP'
full_text = 'Natural Language Processing'

# %%
print('{} stands for {}'.format(abbr,full_text))
# Out:
# NLP stands for Natural Language Processing

# %% [markdown]
# Task 2:
# Create a function which takes N as an argument and return a list repeating the word 'NLP' for N number of times as a string

# %%
def fun(n):
    return('NLP'*n)

# %%
s = fun(5)

# %%
s
# Out:
# 'NLPNLPNLPNLPNLP'

# %% [markdown]
# Task 3:
# From the string variable provided extract Day, Month, year using indexing and print it.

# %%
string= "04-August-2019"

# %%
day = string[:2]
month = string[3:9]
year = string[10:]

# %%
print(day,month,year)
# Out:
# 04 August 2019

# %% [markdown]
# Task 4:
# Extract Supervisedlearning from the following string.

# %%
string = "SSuuppeerrvviisseeddlleeaarrnniinng"
str1 = string[::2]

# %%
str1
# Out:
# 'Supervisedlearning'

# %% [markdown]
# Task 5:
# Navigate to this drive link and download owlcreek.txt file and read it into a python string. Then print the length of the string.

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\91706'

# %%
os.chdir(path = "C:\\Users\\91706\\Downloads")

# %%
myfile = open('owlcreek.txt')
str1 = myfile.read()

# %%
len(str1)
# Out:
# 21344

# %% [markdown]
# Task 6:
# In the text after every full stop (.) there are two trailling spaces, reduce it to single trailling space and save the changed string to a new file "new_owlcreek.txt"

# %%
import re

# %%
str2 = re.sub(r"\.[' '][' ']",". ",str1)

# %%
my_file = open("new_owlcreek.txt",'w+')

# %%
my_file.write(str2)
# Out:
# 21211

# %% [markdown]
# Task 7:
# The text is divided into three parts (I, II, III). In the text you can see a 'I' character before starting of first part and similarly 'II' and 'III' for 2nd and 3rd part.
#
# Create three strings dividing these three parts as (part_1, part_2, part_3) and print their character length in the format shown below.

# %%
data = myfile.readlines()

# %%
part1 = "".join(data[data.index("I\n") +1 :data.index("II\n")])

# %%
part2 = "".join(data[data.index("II\n") +1 :data.index("III\n")])

# %%
part3 = "".join(data[data.index("III\n") +1 :])

# %% [markdown]
# Task 8:
# Extract all the sentences within quotes(") in the part_2 that you created in the last task and save it to a variable quotes_part_2

# %%
import re
quotes_part2 = re.findall('''"[^"]+["$]''',(part2))

# %%
for x in quotes_part2[:2]:
    print(x)
# Out:
# "The Yanks are repairing the railroads,"
# "and are
# getting ready for another advance.  They have reached the Owl Creek
# bridge, put it in order and built a stockade on the north bank.  The
# commandant has issued an order, which is posted everywhere, declaring
# that any civilian caught interfering with the railroad, its bridges,
# tunnels, or trains will be summarily hanged.  I saw the order."

# %% [markdown]
# Task 9:
# Convert part_1 string to lowercase using string function

# %%
part1.lower()
# Out:
# '\na man stood upon a railroad bridge in northern alabama, looking down\ninto the swift water twenty feet below.  the man\'s hands were behind\nhis back, the wrists bound with a cord.  a rope closely encircled his\nneck.  it was attached to a stout cross-timber above his head and the\nslack fell to the level of his knees.  some loose boards laid upon the\nties supporting the rails of the railway supplied a footing for him\nand his executioners--two private soldiers of the federal army,\ndirected by a sergeant who in civil life may have been a deputy\nsheriff.  at a short remove upon the same temporary platform was an\nofficer in the uniform of his rank, armed.  he was a captain.  a\nsentinel at each end of the bridge stood with his rifle in the\nposition known as "support," that is to say, vertical in front of the\nleft shoulder, the hammer resting on the forearm thrown straight\nacross the chest--a formal and unnatural position, enforcing an erect\ncarriage of the body.  it did not 
# ...

# %% [markdown]
# Task 10:
# Remove all the punctuation marks from the words

# %%
import string

# %%
s = ""
for x in str1:
    if x not in string.punctuation:
           s = s + x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-131-b7883366729c> in <module>
#       1 s = ""
#       2 for x in str1:
# ----> 3     if x not in string.punctuation:
#       4            s = s + x
#       5
#
# NameError: name 'string' is not defined

# %% [markdown]
# Task 11:
# Split the lowercase part_1 string into words, save it to a variable called words_list and then print the number of words or length of the list.

# %%
words_list = part1.split()

# %%
len(words_list)
# Out:
# 1057

# %% [markdown]
# Task 12
# Download this Business_Proposal.pdf file from this link and put it in your current working directory.
#
# Now read the pdf file. Check the second page it has name of the authors, From this page extract the Name , position and Email Id and put it into a DataFrame contacts shown below

# %%
os.getcwd()
# Out:
# 'C:\\Users\\91706\\Downloads'

# %%
# !pip install PyPDF2
# Out:
# ^C

# %%
import PyPDF2

# %%
f = open('Business_Proposal.pdf','rb')

# %%
pdf_reader = PyPDF2.PdfFileReader(f)

# %%
page2 = pdf_reader.getPage(1)

# %%
page2text = page2.extractText()

# %%
f.close()

# %%
print(page2text)
# Out:
# AUTHORS:
#
# Amy Baker, Finance Chair, x345, abaker@ourcompany.com
#
# Chris Donaldson, Accounting Dir., x621, cdonaldson@ourcompany.com
#
# Erin Freeman, Sr. VP, x879, efreeman@ourcompany.com

# %%
l1 = page2text.split('\n \n')

# %%
l1 = l1[1:-1]

# %%
l2 = []
for x in l1[:]:
    a = x.split(',')
    l2.append(a)

# %%
import pandas as pd

# %%
df = pd.DataFrame(l2,index = None, columns = ['Name','Designation','Xcode','Email id'])

# %%
df
# Out:
#               Name       Designation  Xcode                    Email id
# 0        Amy Baker     Finance Chair   x345       abaker@ourcompany.com
# 1  Chris Donaldson   Accounting Dir.   x621   cdonaldson@ourcompany.com
# 2     Erin Freeman            Sr. VP   x879     efreeman@ourcompany.com

# %% [markdown]
# Task 13
# Run the below code to import the Amazon reviews Dataset.

# %%
# !pip install wget

# %%
import wget
wget.download('http://snap.stanford.edu/data/amazon/productGraph/categoryFiles/reviews_Cell_Phones_and_Accessories_5.json.gz')

# %%
import pandas as pd

# %%
df = pd.read_json('reviews_Cell_Phones_and_Accessories_5.json.gz', lines=True, compression='gzip')

# %% [markdown]
# Check for the existence of NaN values in a reviewText columns

# %%
pd.isna(df['reviewText'])
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 194409    False
# 194410    False
# 194411    False
# 194412    False
# 194413    False
# 194414    False
# 194415    False
# 194416    False
# 194417    False
# 194418    False
# 194419    False
# 194420    False
# 194421    False
# 194422    False
# 194423    False
# 194424    False
# 194425    False
# 194426    False
# 194427    False
# 194428    False
# 194429    False
# 194430    False
# 194431    False
# 194432    False
# ...

# %%
df
# Out:
#               asin   helpful  overall  \
# 0       120401325X    [0, 0]        4
# 1       120401325X    [0, 0]        5
# 2       120401325X    [0, 0]        5
# 3       120401325X    [4, 4]        4
# 4       120401325X    [2, 3]        5
# 5       120401325X    [1, 2]        3
# 6       120401325X    [0, 0]        5
# 7       3998899561    [1, 2]        1
# 8       3998899561    [2, 3]        5
# 9       3998899561    [1, 1]        5
# 10      3998899561    [0, 0]        5
# 11      3998899561    [2, 3]        5
# 12      3998899561    [3, 3]        5
# 13      3998899561  [12, 16]        5
# 14      3998899561    [1, 1]        5
# 15      3998899561    [0, 0]        5
# 16      3998899561    [2, 3]        5
# 17      6073894996    [0, 0]        5
# 18      6073894996    [2, 3]        5
# 19      6073894996    [0, 0]        1
# 20      6073894996    [0, 0]        5
# 21      6073894996    [0, 0]        5
# 22      6073894996    [0, 0]        3
# ...

# %% [markdown]
# Task 14
# Get the word count in each datapoint and create a new column 'word_count' and then print the head of reviewText and Word_Count

# %%
i = 0
for x in df['reviewText']:
    l1 = x.split()
    df.at[i, 'word_count'] = len(l1)
    i += 1

# %%
df[['word_count','reviewText']]
# Out:
#         word_count                                         reviewText
# 0             37.0  They look good and stick good! I just don't li...
# 1             32.0  These stickers work like the review says they ...
# 2             34.0  These are awesome and make my phone look so st...
# 3             51.0  Item arrived in great time and was in perfect ...
# 4             23.0  awesome! stays on, and looks great. can be use...
# 5             23.0  These make using the home button easy. My daug...
# 6             23.0  Came just as described.. It doesn't come unstu...
# 7             20.0  it worked for the first week then it only char...
# 8             44.0  Good case, solid build. Protects phone all aro...
# 9             35.0  This is a fantastic case. Very stylish and pro...
# 10            21.0  this case fits perfectly on the s4 and keeps m...
# 11            71.0  This is the first battery case I have had for ...
# ...

# %% [markdown]
# Task 15
# Lowercase all the texts is reviewText and print the head of reviews

# %%
i = 0
for x in df['reviewText']:
    df.at[i,'reviewText'] = x.lower()
    i += 1

# %%
df['reviewText']
# Out:
# 0         they look good and stick good! i just don't li...
# 1         these stickers work like the review says they ...
# 2         these are awesome and make my phone look so st...
# 3         item arrived in great time and was in perfect ...
# 4         awesome! stays on, and looks great. can be use...
# 5         these make using the home button easy. my daug...
# 6         came just as described.. it doesn't come unstu...
# 7         it worked for the first week then it only char...
# 8         good case, solid build. protects phone all aro...
# 9         this is a fantastic case. very stylish and pro...
# 10        this case fits perfectly on the s4 and keeps m...
# 11        this is the first battery case i have had for ...
# 12        performs exactly as advertised . it's very  st...
# 13        unlike most of the rechargeable battery cases,...
# 14        just what i needed. i needed a phone case for ...
# 15        when there is no outlets, or chargers near by ...
# ...

# %% [markdown]
# Task 16
# Remove all the punctuations from the reviewText Column and print the head of reviews

# %%
i = 0
for x in df['reviewText']:
    for y in x:
        if y in string.punctuation:
            x = x.replace(y,"")
    df.at[i,'reviewText'] = x
    i += 1

# %%
df['reviewText']
# Out:
# 0         they look good and stick good i just dont like...
# 1         these stickers work like the review says they ...
# 2         these are awesome and make my phone look so st...
# 3         item arrived in great time and was in perfect ...
# 4         awesome stays on and looks great can be used o...
# 5         these make using the home button easy my daugh...
# 6         came just as described it doesnt come unstuck ...
# 7         it worked for the first week then it only char...
# 8         good case solid build protects phone all aroun...
# 9         this is a fantastic case very stylish and prot...
# 10        this case fits perfectly on the s4 and keeps m...
# 11        this is the first battery case i have had for ...
# 12        performs exactly as advertised  its very  stur...
# 13        unlike most of the rechargeable battery cases ...
# 14        just what i needed i needed a phone case for m...
# 15        when there is no outlets or chargers near by i...
# ...

# %% [markdown]
# Task 17
# Split the text in reviewText list of words and print the head of reviews

# %%
i = 0
for x in df['reviewText']:
    df.at[i,'reviewText'] = x.split()
    i += 1

# %%
df['reviewText']
# Out:
# 0         [they, look, good, and, stick, good, i, just, ...
# 1         [these, stickers, work, like, the, review, say...
# 2         [these, are, awesome, and, make, my, phone, lo...
# 3         [item, arrived, in, great, time, and, was, in,...
# 4         [awesome, stays, on, and, looks, great, can, b...
# 5         [these, make, using, the, home, button, easy, ...
# 6         [came, just, as, described, it, doesnt, come, ...
# 7         [it, worked, for, the, first, week, then, it, ...
# 8         [good, case, solid, build, protects, phone, al...
# 9         [this, is, a, fantastic, case, very, stylish, ...
# 10        [this, case, fits, perfectly, on, the, s4, and...
# 11        [this, is, the, first, battery, case, i, have,...
# 12        [performs, exactly, as, advertised, its, very,...
# 13        [unlike, most, of, the, rechargeable, battery,...
# 14        [just, what, i, needed, i, needed, a, phone, c...
# 15        [when, there, is, no, outlets, or, chargers, n...
# ...

# %% [markdown]
# Task 18
# Remove all the words that contain numbers in reviewText column and print the head of reviews

# %%
for x in df['reviewText']:
    for y in x:
        if y.isalpha() is False :
            x.pop(x.index(y))

# %%
df['reviewText']
# Out:
# 0         [they, look, good, and, stick, good, i, just, ...
# 1         [these, stickers, work, like, the, review, say...
# 2         [these, are, awesome, and, make, my, phone, lo...
# 3         [item, arrived, in, great, time, and, was, in,...
# 4         [awesome, stays, on, and, looks, great, can, b...
# 5         [these, make, using, the, home, button, easy, ...
# 6         [came, just, as, described, it, doesnt, come, ...
# 7         [it, worked, for, the, first, week, then, it, ...
# 8         [good, case, solid, build, protects, phone, al...
# 9         [this, is, a, fantastic, case, very, stylish, ...
# 10        [this, case, fits, perfectly, on, the, and, ke...
# 11        [this, is, the, first, battery, case, i, have,...
# 12        [performs, exactly, as, advertised, its, very,...
# 13        [unlike, most, of, the, rechargeable, battery,...
# 14        [just, what, i, needed, i, needed, a, phone, c...
# 15        [when, there, is, no, outlets, or, chargers, n...
# ...

# %%
df['reviewText']= [' '.join(review) for review in df['reviewText']]
df['reviewText'].head()
# Out:
# 0    they look good and stick good i just dont like...
# 1    these stickers work like the review says they ...
# 2    these are awesome and make my phone look so st...
# 3    item arrived in great time and was in perfect ...
# 4    awesome stays on and looks great can be used o...
# Name: reviewText, dtype: object

# %%
df['reviewText']
# Out:
# 0         they look good and stick good i just dont like...
# 1         these stickers work like the review says they ...
# 2         these are awesome and make my phone look so st...
# 3         item arrived in great time and was in perfect ...
# 4         awesome stays on and looks great can be used o...
# 5         these make using the home button easy my daugh...
# 6         came just as described it doesnt come unstuck ...
# 7         it worked for the first week then it only char...
# 8         good case solid build protects phone all aroun...
# 9         this is a fantastic case very stylish and prot...
# 10        this case fits perfectly on the and keeps me p...
# 11        this is the first battery case i have had for ...
# 12        performs exactly as advertised its very sturdi...
# 13        unlike most of the rechargeable battery cases ...
# 14        just what i needed i needed a phone case for m...
# 15        when there is no outlets or chargers near by i...
# ...

# %% [markdown]
# Task 19
# For the following assignments we will use a tweets Data. Elon Musk Tweets-Until 4/6/17
#
# For all the following tasks use Regular expressions
#
# Click on th link download the csv and place it in your current working directory.
#
# Read the elonmusk_tweets.csv and print head of the text column

# %%
os.getcwd()
# Out:
# 'C:\\Users\\91706'

# %%
df_elon = pd.read_csv("elonmusk_tweets.csv", usecols = ['id','created_at','text'])

# %%
df_elon.dtypes
# Out:
# id            float64
# created_at     object
# text           object
# dtype: object

# %% [markdown]
# Task 20
# Extract all the links from the tweets and put it in a lists naming it tweets_links. After Extracting print first five links and total number of links.

# %%
import re

# %%
tweets_links = []
for x in df_elon['text']:
    y = (re.findall(r'''http[s|:]\S+''',x))
    if y != [] :
        if len(y) == 1:
            tweets_links.append(y[0])
        else:
            for x in y:
                tweets_links.append(x)

# %%
for x in tweets_links[:5]:
    print(x)
print(len(tweets_links))
# Out:
# https://t.co/v7JUJQWfCv'
# https://t.co/qQcTqkzgMl"
# https://t.co\xe2\x80\xa6"
# https://t.co/68nMJkiPsC'
# https://t.co/XtgQGwJ21D'
# 1262

# %% [markdown]
# Task 21
# Extract all the @mentions from the tweets and put it in a lists naming it tweets_mentions. After Extracting print first five mentions and total number of mentions.

# %%
tweets_mentions = []
for x in df_elon['text']:
    y = (re.findall(r'''@\S+''',x))
    if y != [] :
        if len(y) == 1:
            tweets_mentions.append(y[0])
        else:
            for x in y:
                tweets_mentions.append(x)

# %%
for x in tweets_mentions[:5]:
    print(x)
print(len(tweets_mentions))
# Out:
# @ForIn2020
# @waltmossberg
# @mims
# @defcon_5
# @waltmossberg
# 2278

# %% [markdown]
# Task 22
# Extract all the #Hashtags from the tweets and put it in a lists naming it tweets_hastags. After Extracting print first five hastags and total number of hastags.

# %%
tweets_hastags = []
for x in df_elon['text']:
    y = (re.findall(r'''#\S+''',x))
    if y != [] :
        if len(y) == 1:
            tweets_hastags.append(y[0])
        else:
            for x in y:
                tweets_hastags.append(x)

# %%
for x in tweets_hastags[:5]:
    print(x)
print(len(tweets_hastags))
# Out:
# #%*&gt;
# #Dragon
# #breakapod
# #IridiumNEXT
# #NEXTevolutio\xe2\x80\xa6'
# 154

# %% [markdown]
# Task 23
# Remove all the links , hastags and mentions from the clean_tweets and overwrite it. After done cleaning print the head() of the clean data.

# %%
i =0
for x in df_elon['text']:
    a = re.sub(r'''http[s|:]\S+''','',x)
    a = re.sub(r'''@\S+''','',a)
    a = re.sub(r'''#\S+''','',a)
    df_elon.at[i,'text'] = a
    i += 1

# %%
for x in df_elon['text']:
    print(x)
# Out:
# b'And so the robots spared humanity ...
# b"    Exactly. Tesla is absurdly overvalued if based on the past, but that's irr\xe2\x80\xa6
# b'   Et tu, Walt?'
# b'Stormy weather in Shortville ...'
# b"  Coal is dying due to nat gas fracking. It's basically dead."
# b" It's just a helicopter in helicopter's clothing"
# b" It won't matter"
# b' Pretty good'
# b"Why did we waste so much time developing silly rockets? Damn you, aliens! So obtuse! You have all this crazy tech, but can't speak English!?"
# b'Technology breakthrough: turns out chemtrails are actually a message from time-traveling aliens describing the secret of teleportation'
# b"RT  We've created the world's first Spam-detecting AI trained entirely in simulation and deployed on a physical robot:
# b'RT  This is extremely important from  and  - reusable rockets bring us MUCH closer to becoming a spacefaring\xe2\x80\xa6'
# b' Def P100D with Ludicrous+, although the rocket starts going a lot faster after that'
# ...
